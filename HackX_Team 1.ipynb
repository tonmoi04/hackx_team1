# %%
import pandas as pd
import os
import csv

# %%
df = pd.read_csv('hackathon - Sheet1.csv')
df
# Out:
#                      Task            StartTime CompletionStatus Priority  \
# 0        English Homework   8/30/2020 15:30:00               no       p3
# 1                Walk Dog    9/30/2020 6:00:00              yes       p2
# 2            Math Project  10/30/2020 15:30:00               no       p3
# 3   Chemistry Experiments   11/30/2020 1:30:00              yes       p3
# 4      Physics lab report  12/30/2020 19:00:00               no       p3
# 5              CS program  13/30/2020 12:30:00              yes       p1
# 6          Eco case study  14/30/2020 11:30:00              yes       p3
# 7                 Spanish   15/30/2020 2:30:00               no       p1
# 8            BST readings  16/30/2020 15:30:00              yes       p3
# 9                     ICT  17/30/2020 16:00:00               no       p2
# 10     Attending webinars  18/30/2020 21:00:00               no       p2
# 11                    Gym   19/30/2020 7:30:00              yes       p2
# ...

# %%
day = input('Enter the day : ')
day = day.lower()
if day == 'monday':
    mondf = df[(df['Days']=='monday')]
    print(mondf)
    x = df.iloc[1,0] 
    y = df.iloc[11,0]
    z = df.iloc[9,0]
    x = str(x)
    y = str(y)
    z = str(z)
    os.system("say you have to " + x)
    os.system("say and " + y)
    os.system("say and " + z)
if day == 'tuesday':
    tuedf = df[(df['Days']=='tuesday')]
    print(tuedf)
    x = df.iloc[0,0] 
    y = df.iloc[14,0]
    x = str(x)
    y = str(y)
    os.system("say you have to " + x)
    os.system("say and " + y)
if day == 'wednesday':
    weddf = df[(df['Days']=='wednesday')]
    print(weddf)
    x = df.iloc[4,0] 
    y = df.iloc[7,0]
    x = str(x)
    y = str(y)
    os.system("say you have to " + x)
    os.system("say and " + y)
if day == 'thursday':
    thudf = df[(df['Days']=='thursday')]
    print(thudf)
    x = df.iloc[2,0] 
    y = df.iloc[15,0]
    x = str(x)
    y = str(y)
    os.system("say you have to " + x)
    os.system("say and " + y)
    
if day == 'friday':
    fridf = df[(df['Days']=='friday')]
    print(fridf)
    x = df.iloc[3,0] 
    x = str(x)
    y = df.iloc[5,0] 
    y = str(y)
    os.system("say you have to " + x)
    os.system("say and " + y)
if day == 'saturday':
    satdf = df[(df['Days']=='saturday')]
    print(satdf)
    x = df.iloc[6,0] 
    y = df.iloc[12,0]
    z = df.iloc[13,0]
    x = str(x)
    y = str(y)
    z = str(z)
    os.system("say you have to " + x)
    os.system("say and " + y)
    os.system("say and " + z)
if day == 'sunday':
    sundf = df[(df['Days']=='sunday')]
    print(sundf)
    x = df.iloc[10,0] 
    x = str(x)
    y = df.iloc[5,0] 
    y = str(y)
    os.system("say you have to " + x)
    os.system("say and " + y)
# Out:
# Enter the day : monday
#         Task            StartTime CompletionStatus Priority    Days
# 1   Walk Dog    9/30/2020 6:00:00              yes       p2  monday
# 9        ICT  17/30/2020 16:00:00               no       p2  monday
# 11       Gym   19/30/2020 7:30:00              yes       p2  monday

# %%
# DONT RUN
fields = ['Task','StartTime','CompletionStatus','Priority','Days']
rows = [ ['English Homework', '8/30/2020 15:30:00', 'no', 'p3', 'tuesday'],  
         ['Walk Dog', '9/30/2020 6:00:00', 'yes', 'p2', 'monday'],  
         ['Math Project', '10/30/2020 15:30:00', 'no', 'p3','thursday'],  
         ['Chemistry Experiments', '11/30/2020 1:30:00', 'yes', 'p3','friday'],  
         ['Physics lab report', '12/30/2020 19:00:00', 'no', 'p3','wednesday'],  
         ['CS program', '13/30/2020 12:30:00', 'yes', 'p1','sunday'],
          ['Eco case study', '14/30/2020 11:30:00', 'yes', 'p3', 'saturday'],  
         ['Spanish', '15/30/2020 2:30:00', 'no', 'p1', 'wednesday'],  
         ['BST readings', '16/30/2020 15:30:00', 'yes', 'p3','friday'],  
         ['ICT', '17/30/2020 16:00:00', 'no', 'p2','monday'],  
         ['Attending webinars', '18/30/2020 21:00:00', 'no', 'p2','sunday'],  
         ['Gym', '19/30/2020 7:30:00', 'yes', 'p2','monday'],
         ['Game', '20/30/2020 14:00:00', 'yes', 'p2', 'saturday'],  
         ['Football', '21/30/2020 17:00:00', 'no', 'p2','saturday'],  
         ['Meals', '22/30/2020 10:30:00', 'yes', 'p4','tuesday'],  
         ['sleep', '23/30/2020 0:00:00', 'no', 'p4','thursday']]
with open(filename, 'w') as csvfile:  
    # creating a csv writer object  
    csvwriter = csv.writer(csvfile)  
        
    # writing the fields  
    csvwriter.writerow(fields)  
        
    # writing the data rows  
    csvwriter.writerows(rows)

# %%
x = df.iloc[1,0] 
y = df.iloc[11,0]
x = str(x)
y = str(y)
os.system("say you have to " + x)
os.system("say and " + y)fields = ['Task','StartTime','CompletionStatus','Priority','Days']
rows = [ ['English Homework', '8/30/2020 15:30:00', 'no', 'p3', 'tuesday'],  
         ['Walk Dog', '9/30/2020 6:00:00', 'yes', 'p2', 'monday'],  
         ['Math Project', '10/30/2020 15:30:00', 'no', 'p3','thursday'],  
         ['Chemistry Experiments', '11/30/2020 1:30:00', 'yes', 'p3','friday'],  
         ['Physics lab report', '12/30/2020 19:00:00', 'no', 'p3','wednesday'],  
         ['CS program', '13/30/2020 12:30:00', 'yes', 'p1','sunday'],
         ['Eco case study', '14/30/2020 11:30:00', 'yes', 'p3', 'saturday'],  
         ['Spanish', '15/30/2020 2:30:00', 'no', 'p1', 'wednesday'],  
         ['BST readings', '16/30/2020 15:30:00', 'yes', 'p3','friday'],  
         ['ICT', '17/30/2020 16:00:00', 'no', 'p2','monday'],  
         ['Attending webinars', '18/30/2020 21:00:00', 'no', 'p2','sunday'],  
         ['Gym', '19/30/2020 7:30:00', 'yes', 'p2','monday'],
         ['Game', '20/30/2020 14:00:00', 'yes', 'p2', 'saturday'],  
         ['Football', '21/30/2020 17:00:00', 'no', 'p2','saturday'],  
         ['Meals', '22/30/2020 10:30:00', 'yes', 'p4','tuesday'],  
         ['sleep', '23/30/2020 0:00:00', 'no', 'p4','thursday']]
with open('hackathon - Sheet1.csv','w') as csvfile:  
    # creating a csv writer object  
    csvwriter = csv.writer(csvfile)  
        
    # writing the fields  
    csvwriter.writerow(fields)  
        
    # writing the data rows  
    csvwriter.writerows(rows)
# Out:
# 0

# %%
my_list = []
a = str(input('Enter task'))
b = str(input('Enter StartTime'))
c = str(input('Enter CompletionStatus'))
d = str(input('Enter Priority'))
e = str(input('Enter Days'))
my_list.append(a)
my_list.append(b)
my_list.append(c)
my_list.append(d)
my_list.append(e)
rows.append(my_list)
with open('hackathon - Sheet1.csv','w') as csvfile:  
    # creating a csv writer object  
    csvwriter = csv.writer(csvfile)  
        
    # writing the fields  
    csvwriter.writerow(fields)  
        
    # writing the data rows  
    csvwriter.writerows(rows)
# Out:
# [1]

# %%
df
